# %% [markdown]
# ## This notebook will primarily be used for th Applied Data Science Capstone course.

# %%
import pandas as pd
import numpy as np
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
